# %%
import pandas as pd

# %% [markdown]
# ### Loading Dataset

# %%
# Data with Header
data = pd.read_csv("/Users/shyamgoyal/Desktop/UCI/Full Stack Data Scientist/pima-indians-diabetes.csv")

# %%
data.head(10)
# Out:
#    Preg  Plas  Pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1
# 3     1    89    66    23    94  28.1  0.167   21      0
# 4     0   137    40    35   168  43.1  2.288   33      1
# 5     5   116    74     0     0  25.6  0.201   30      0
# 6     3    78    50    32    88  31.0  0.248   26      1
# 7    10   115     0     0     0  35.3  0.134   29      0
# 8     2   197    70    45   543  30.5  0.158   53      1
# 9     8   125    96     0     0   0.0  0.232   54      1

# %%
#Data with No Header
data1 =  pd.read_csv("/Users/shyamgoyal/Desktop/UCI/Full Stack Data Scientist/diabetes.csv", 
                     names = ['h1','h2','h3','h4','h5','h6','h7','h8','h9'])

# %%
data1
# Out:
#      h1   h2  h3  h4   h5    h6     h7  h8  h9
# 0     6  148  72  35    0  33.6  0.627  50   1
# 1     1   85  66  29    0  26.6  0.351  31   0
# 2     8  183  64   0    0  23.3  0.672  32   1
# 3     1   89  66  23   94  28.1  0.167  21   0
# 4     0  137  40  35  168  43.1  2.288  33   1
# ..   ..  ...  ..  ..  ...   ...    ...  ..  ..
# 763  10  101  76  48  180  32.9  0.171  63   0
# 764   2  122  70  27    0  36.8  0.340  27   0
# 765   5  121  72  23  112  26.2  0.245  30   0
# 766   1  126  60   0    0  30.1  0.349  47   1
# 767   1   93  70  31    0  30.4  0.315  23   0
#
# [768 rows x 9 columns]

# %%
# Import data form URL

# %%
# Import data from text file
#data4 = pd.read_csv()

# %%
# Import data from excel , Library used "pip install xlrd==1.2.0"
#data6 = pd.read_excel()

# %%
data7 = pd.read_csv("/Users/shyamgoyal/Desktop/UCI/Full Stack Data Scientist/pima-indians-diabetes.csv", skiprows=5, header=None)

# %%
data7
# Out:
#       0    1   2   3    4     5      6   7  8
# 0     0  137  40  35  168  43.1  2.288  33  1
# 1     5  116  74   0    0  25.6  0.201  30  0
# 2     3   78  50  32   88  31.0  0.248  26  1
# 3    10  115   0   0    0  35.3  0.134  29  0
# 4     2  197  70  45  543  30.5  0.158  53  1
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 759  10  101  76  48  180  32.9  0.171  63  0
# 760   2  122  70  27    0  36.8  0.340  27  0
# 761   5  121  72  23  112  26.2  0.245  30  0
# 762   1  126  60   0    0  30.1  0.349  47  1
# 763   1   93  70  31    0  30.4  0.315  23  0
#
# [764 rows x 9 columns]

# %% [markdown]
# ### Understanding your data with Descriptive Statistics

# %%
'''
Understanding your datset with Descriptove Statistics(Things to check in a Dataset)

1. Peeking the data
data.head(10)
data.tail(50)

2. Dimensions of your data
data.shape

3. Checking data type
data.dtypes

4. Skipping rows
data7 = pd.read_csv("/Full Stack Data Scientist/pima-indians-diabetes.csv", skiprows=5, header=None)


4. Descriptive statistics
data.describe()
data.describe().T (To transpose the data)

5. Class Distribution(Classification Only)
data['dependent variable'].value_counts()

6. Correlations Between Attributes
data.corr(method = 'pearson') # ByDefault
data.corr(method = 'kendall')

7. Skewness of Univariate distributions
data.skew()

8. Missing Values
data.isnull().sum() (count all the TRUE values)

'''


'''
Understanding your data with Visualizations

import matplotlib.pyplot as plt

1. Univariate Plots

1.1 Histograms(Gives an Idea how aur data is distributed)
data.hist(figsize=(10,8))
plt.show()

1.2 Density Plots
data.plot(kind= 'density', subplots= True, layout = (3,3), sharex = False, figsize=(15,10))
plt.show()

1.3 Box and Whisker Plots(To check the Outliers)
data.plot(kind= 'box', subplots= True, layout = (3,3), sharex = False, sharey = False, figsize=(15,10))
plt.show()

2. Multivariate Plots

import seaborn as sns

2.1 Correlation Matrix Plot
plt.figure(figsize(15,10))
sns.heatmap(data.corr(), annot = True)

2.2 Scatter Plot Matrix
pd.plotting.scatter_matrix(data, figsize=(15,10))
plt.show()

'''
# Out:
# "\nUnderstanding your data with Visualizations\n\nimport matplotlib.pyplot as plt\n\n1. Univariate Plots\n\n1.1 Histograms(Gives an Idea how aur data is distributed)\ndata.hist(figsize=(10,8))\nplt.show()\n\n1.2 Density Plots\ndata.plot(kind= 'density', subplots= True, layout = (3,3), sharex = False, figsize=(15,10))\nplt.show()\n\n1.3 Box and Whisker Plots(To check the Outliers)\ndata.plot(kind= 'box', subplots= True, layout = (3,3), sharex = False, sharey = False, figsize=(15,10))\nplt.show()\n\n2. Multivariate Plots\n\n2.1 Correlation Matrix Plot\n\n2.2 Scatter Plot Matrix\n\n"

# %%
data.head(10)
# Out:
#    Preg  Plas  Pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1
# 3     1    89    66    23    94  28.1  0.167   21      0
# 4     0   137    40    35   168  43.1  2.288   33      1
# 5     5   116    74     0     0  25.6  0.201   30      0
# 6     3    78    50    32    88  31.0  0.248   26      1
# 7    10   115     0     0     0  35.3  0.134   29      0
# 8     2   197    70    45   543  30.5  0.158   53      1
# 9     8   125    96     0     0   0.0  0.232   54      1

# %%
data.shape
# Out:
# (768, 9)

# %%
data.dtypes
# Out:
# Preg       int64
# Plas       int64
# Pres       int64
# skin       int64
# test       int64
# mass     float64
# pedi     float64
# age        int64
# class      int64
# dtype: object

# %%
data.describe()
# Out:
#              Preg        Plas        Pres        skin        test        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age       class
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# ...

# %%
data.describe().T
# Out:
#        count        mean         std     min       25%       50%        75%  \
# Preg   768.0    3.845052    3.369578   0.000   1.00000    3.0000    6.00000
# Plas   768.0  120.894531   31.972618   0.000  99.00000  117.0000  140.25000
# Pres   768.0   69.105469   19.355807   0.000  62.00000   72.0000   80.00000
# skin   768.0   20.536458   15.952218   0.000   0.00000   23.0000   32.00000
# test   768.0   79.799479  115.244002   0.000   0.00000   30.5000  127.25000
# mass   768.0   31.992578    7.884160   0.000  27.30000   32.0000   36.60000
# pedi   768.0    0.471876    0.331329   0.078   0.24375    0.3725    0.62625
# age    768.0   33.240885   11.760232  21.000  24.00000   29.0000   41.00000
# class  768.0    0.348958    0.476951   0.000   0.00000    0.0000    1.00000
#
#           max
# Preg    17.00
# Plas   199.00
# Pres   122.00
# skin    99.00
# test   846.00
# mass    67.10
# pedi     2.42
# age     81.00
# class    1.00

# %%
data['class'].value_counts()
# Out:
# 0    500
# 1    268
# Name: class, dtype: int64

# %%
data.corr()
# Out:
#            Preg      Plas      Pres      skin      test      mass      pedi  \
# Preg   1.000000  0.129459  0.141282 -0.081672 -0.073535  0.017683 -0.033523
# Plas   0.129459  1.000000  0.152590  0.057328  0.331357  0.221071  0.137337
# Pres   0.141282  0.152590  1.000000  0.207371  0.088933  0.281805  0.041265
# skin  -0.081672  0.057328  0.207371  1.000000  0.436783  0.392573  0.183928
# test  -0.073535  0.331357  0.088933  0.436783  1.000000  0.197859  0.185071
# mass   0.017683  0.221071  0.281805  0.392573  0.197859  1.000000  0.140647
# pedi  -0.033523  0.137337  0.041265  0.183928  0.185071  0.140647  1.000000
# age    0.544341  0.263514  0.239528 -0.113970 -0.042163  0.036242  0.033561
# class  0.221898  0.466581  0.065068  0.074752  0.130548  0.292695  0.173844
#
#             age     class
# Preg   0.544341  0.221898
# Plas   0.263514  0.466581
# Pres   0.239528  0.065068
# skin  -0.113970  0.074752
# test  -0.042163  0.130548
# mass   0.036242  0.292695
# ...

# %%
data.corr(method = 'kendall')
# Out:
#            Preg      Plas      Pres      skin      test      mass      pedi  \
# Preg   1.000000  0.091323  0.135440 -0.064401 -0.096417  0.004183 -0.029959
# Plas   0.091323  1.000000  0.159961  0.039046  0.163645  0.155862  0.061871
# Pres   0.135440  0.159961  1.000000  0.094868 -0.003682  0.205222  0.019448
# skin  -0.064401  0.039046  0.094868  1.000000  0.420066  0.331532  0.126457
# test  -0.096417  0.163645 -0.003682  0.420066  1.000000  0.141587  0.161652
# mass   0.004183  0.155862  0.205222  0.331532  0.141587  1.000000  0.094644
# pedi  -0.029959  0.061871  0.019448  0.126457  0.161652  0.094644  1.000000
# age    0.458272  0.196510  0.246056 -0.044754 -0.080176  0.088678  0.028042
# class  0.170370  0.390565  0.119206  0.076297  0.058531  0.253676  0.143359
#
#             age     class
# Preg   0.458272  0.170370
# Plas   0.196510  0.390565
# Pres   0.246056  0.119206
# skin  -0.044754  0.076297
# test  -0.080176  0.058531
# mass   0.088678  0.253676
# ...

# %%
data.skew()
# Out:
# Preg     0.901674
# Plas     0.173754
# Pres    -1.843608
# skin     0.109372
# test     2.272251
# mass    -0.428982
# pedi     1.919911
# age      1.129597
# class    0.635017
# dtype: float64

# %%
data.isnull()
# Out:
#       Preg   Plas   Pres   skin   test   mass   pedi    age  class
# 0    False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...
# 763  False  False  False  False  False  False  False  False  False
# 764  False  False  False  False  False  False  False  False  False
# 765  False  False  False  False  False  False  False  False  False
# 766  False  False  False  False  False  False  False  False  False
# 767  False  False  False  False  False  False  False  False  False
#
# [768 rows x 9 columns]

# %%
data.isnull().sum()
# Out:
# Preg     0
# Plas     0
# Pres     0
# skin     0
# test     0
# mass     0
# pedi     0
# age      0
# class    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
data.hist(figsize=(10,8))
plt.show()

# %%
data.plot(kind = 'density', subplots= True, layout=(3,3), sharex = False, figsize=(15,10))
plt.show()

# %%
data.plot(kind= 'box', subplots= True, layout = (3,3), sharex = False, sharey = False, figsize=(15,10))
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
pd.plotting.scatter_matrix(data, figsize=(15,10))
plt.show()
